# %%
In [1]: %matplotlib inline

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.asarray(Image.open('../../pythonPractice/Matplotlib/1654.png'))
print(repr(img))
# Out:
# array([[ 8,  3,  8, ..., 10, 10, 10],
#        [ 8,  8,  8, ..., 10, 10, 10],
#        [ 8,  8,  8, ..., 10, 10,  3],
#        ...,
#        [ 5, 13, 13, ..., 30, 30, 30],
#        [13, 13, 38, ..., 30, 30, 30],
#        [ 5, 13, 13, ..., 30, 30, 30]], dtype=uint8)

# %%
imgplot = plt.imshow(img)
